# %%
# Program : For converting a audio clip into a sperctrogram
# Written by : Leo pauly | leopauly314@gmail.com

# %%
import wave
from scipy.io import wavfile
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
import os
import pylab

# %% [markdown]
# #### Method 1

# %%
def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    (Pxx, freqs, bins, im)=pylab.specgram(sound_info, NFFT=512, Fs=frame_rate)
    print(Pxx.shape)
    Pxx=np.log(Pxx)
    plt.imshow(Pxx)
    plt.show()
    #pylab.show()
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'Int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

# %% [markdown]
# #### Class : Street music

# %%
wav_file = 'streetmusic.wav'
graph_spectrogram(wav_file)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   app.launch_new_instance()
# (257, 918)

# %% [markdown]
# #### Class : Dog bark

# %%
wav_file = 'dogbark.wav'
graph_spectrogram(wav_file)
# Out:
# (257, 72)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   app.launch_new_instance()

# %% [markdown]
# #### Class : Siren

# %%
wav_file = 'siren.wav'
graph_spectrogram(wav_file)
# Out:
# (257, 918)
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:16: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   app.launch_new_instance()
